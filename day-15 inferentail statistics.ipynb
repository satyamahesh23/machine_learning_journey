# %%
import numpy as np

# %%
data=np.random.binomial(10,0.5,100)
print(data)
# Out:
# [6 5 7 5 3 5 6 4 8 5 5 5 7 5 5 7 5 6 7 5 5 3 9 5 5 4 5 7 7 7 5 6 5 6 3 4 4
#  3 3 6 3 5 5 2 4 5 7 4 7 5 5 7 6 5 6 8 5 5 3 5 3 7 2 7 6 5 2 4 6 6 3 3 5 5
#  7 2 3 5 6 5 6 6 4 5 5 3 6 5 7 4 5 4 4 2 7 9 8 6 3 4]
