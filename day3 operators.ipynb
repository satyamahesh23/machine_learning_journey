# %% [markdown]
# # operators

# %%
# a+b
#a,b are operands
# + are operator

# %% [raw]
# operators
# 1)arithematic
# 2)assignment
# 3)logical
# 4)conditional
# 5)bitwise
# 6)membership
# 7)identity

# %%
# arthimatic: +,-,/,*,**,//,%

# %%
a=10
b=20
a+b
# Out:
# 30

# %%
print(7//2)
# Out:
# 3
