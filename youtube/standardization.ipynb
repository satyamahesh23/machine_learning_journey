# %%
import pandas as pd

# %%
from sklearn.preprocessing import StandardScaler

# %%
df=pd.DataFrame({ # # dataset with an outlier
    'age':    [25, 30, 28, 35, 27], # # normal age values — no outliers
  'salary': [30000, 55000, 45000, 80000, 900000] # # 900000 is a massive outlier — will distort normalization

})
sc=StandardScalar()
df_std=sc.fit_transform(df)
print(sc.mean_)
result=pd.DataFrame(df_std,columns=df.columns)
print(result.round(2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9768/2793324579.py in <module>
#       4
#       5 })
# ----> 6 sc=StandardScalar()
#       7 df_std=sc.fit_transform(df)
#       8 print(sc.mean_)
#
# NameError: name 'StandardScalar' is not defined
