# %% [markdown]
# # function

# %% [raw]
# functions are the block of code only runs whenn it is called.
# advantages of function:
# 1) reuse
# 2) flexibility
#
# different types of functions:
#
# 1.built in functions. print(),type()
# 2. user defined functions.  our own program we can use n number of times
# 3. anonymous function
# 4. recursive function

# %% [raw]
# # syntax
# def function_name(parameters1,2,3)#parameters completely depends on requirement of program n number of parameters we can define
# body of the function
# print()/return
# calling the function
# #funcion_name(parameter values as arguments 1,2,3)

# %%
#sum of two numbers using functions
def sum_1(num_1,num_2):
    return (num_1+num_2)
sum_1(2,4)
#this is temporary output
# Out:
# 6

# %%
#when to use print and when to use return

# %%
def sub_1(a,b):
    return (a-b)
sub_1(2,5)
#this is temporary output
# Out:
# -3

# %%
def master_1(a1,a2):
    ans_1=sum_1(a1,a2)
    ans_2=sub_1(a1,a2)
    print(ans_1,ans_2)
master_1(30,40)
# we are using the funtions in this block so thats why we can use functions n nuumbers of times that why they called reuseable block of code
#this is permanent output
# Out:
# 70 -10

# %% [raw]
# # if we write print it is permanent output
# #if we write return we use our code in any other code function we use it

# %% [markdown]
# # variable length arguments exceptions

# %%
def sum_n(*param_1):
    sum_1=0
    for i in param_1:
        sum_1=sum_1+i
    print(sum_1)
sum_n(10,20,30)
#if we write * this we can keep so many arguments
# Out:
# 60

# %% [markdown]
# # anonymous functions:

# %%
lambda arguments_1,2,3:expression like arg1+arg2

# %% [markdown]
# # recrusive function

# %% [raw]
# recrusive function are the function that call themselves in the definition of it.
# syntax:::
# def name_of_function(parameters1,....):
# .......
#
# name_of_function(arg,.....)
# call:
# name_of_functions(arg....)

# %%
def factorial(x):
    if x==1:
        return 1
    else:
        return x * factorial(x-1)
factorial(5)
# Out:
# 120
