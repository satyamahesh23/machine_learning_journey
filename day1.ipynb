# %% [markdown]
# # primitive datatypes

# %% [markdown]
# # int, float, string, boolean, nun

# %%
num_1=56
print(num_1)
# Out:
# 56

# %% [markdown]
# ##type() is a built in function

# %%
print(type(num_1))
# Out:
# <class 'int'>

# %% [markdown]
# # float:

# %%
x=56.0
print(type(x))
# Out:
# <class 'float'>

# %% [markdown]
# ## python is a case sensitive:
