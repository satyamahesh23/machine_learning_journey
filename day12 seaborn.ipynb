# %% [raw]
# What is Seaborn?
#
# Seaborn is a Python library for creating beautiful statistical graphs.
#
# It is built on top of Matplotlib.
#
# Think of it as:
#
# NumPy      → Numbers
# Pandas     → Tables
# Matplotlib → Basic Graphs
# Seaborn    → Beautiful Graphs + Statistics
#
#
#
# Installation
# pip install seaborn
#
# Import:
#
# import seaborn as sns
# import matplotlib.pyplot as plt

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 26.1.2 is available.
# You should consider upgrading via the 'C:\Users\pavani\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
days=[1,2,3,4,5]
sales=[10,15,13,18,21]
sns.lineplot(x=days,y=sales)
# Out:
# <Axes: >

# %%
players=['virat','kohli','gill']
score=[200,300,400]
sns.barplot(x=players,y=score)
# Out:
# <Axes: >

# %%
marks = [50,60,70,80,90,85,75,65]

sns.histplot(marks)

plt.show()

# %%
help(sns)
# Out:
# Help on package seaborn:
#
# NAME
#     seaborn - # Import seaborn objects
#
# PACKAGE CONTENTS
#     _base
#     _compat
#     _core (package)
#     _docstrings
#     _marks (package)
#     _statistics
#     _stats (package)
#     _testing
#     algorithms
#     axisgrid
#     categorical
#     cm
#     colors (package)
#     distributions
#     external (package)
#     matrix
#     miscplot
#     objects
#     palettes
#     rcmod
#     regression
#     relational
#     utils
#     widgets
#
# DATA
#     crayons = {'Almond': '#EFDECD', 'Antique Brass': '#CD9575', 'Apricot':...
#     xkcd_rgb = {'acid green': '#8ffe09', 'adobe': '#bd6c48', 'algae': '#54...
#
# VERSION
#     0.13.2
#
# FILE
#     c:\users\pavani\appdata\local\programs\python\python310\lib\site-packages\seaborn\__init__.py

# %%
height = [150,160,170,180]
weight = [50,60,70,80]
sns.scatterplot(x=height,y=weight)
# Out:
# <Axes: >

# %%
sns.boxplot(x=height)
# Out:
# <Axes: >

# %%
import pandas as pd
data=pd.DataFrame([[80,85,90],
     [75,70,95],
     [60,65,88]],
                 columns=['python','sql','ml'])
sns.heatmap(data)
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

players = ["Virat","Rohit","Gill","Rahul"]
runs = [90,45,100,56]

sns.barplot(x=players, y=runs)

plt.title("India Scorecard")

plt.show()

# %%
sns.heatmap(
    df[["Python","SQL","ML"]],
    annot=True,
    cmap="YlGnBu"
)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3636/4144903088.py in <module>
#       1 sns.heatmap(
# ----> 2     df[["Python","SQL","ML"]],
#       3     annot=True,
#       4     cmap="YlGnBu"
#       5 )
#
# NameError: name 'df' is not defined

# %%
import numpy as np

python_marks = np.array([90,85,78,92,88])
sql_marks = np.array([80,75,85,95,70])
ml_marks = np.array([85,90,80,88,92])

print("Python Marks:", python_marks)
# Out:
# Python Marks: [90 85 78 92 88]

# %%
import pandas as pd
df=pd.DataFrame=({
    "name":['satya','ravi','sai','ajay',"rahul"],
    "python":python_marks,
    "sql":sql_marks,
    "ml_marks":ml_marks
   
})
print(df)
# Out:
# {'name': ['satya', 'ravi', 'sai', 'ajay', 'rahul'], 'python': array([90, 85, 78, 92, 88]), 'sql': array([80, 75, 85, 95, 70]), 'ml_marks': array([85, 90, 80, 88, 92])}
