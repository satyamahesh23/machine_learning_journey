# %% [markdown]
# # pandas

# %% [raw]
# pandas------> panel data
# 1D----vector-----series
# 2D-----matrix------Dataframe

# %%
import pandas as pd

# %%
data=[1,2,3,4,5]
data_1=pd.DataFrame(data)
print(data_1)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
hello=pd.Series(data=[10,20,30,40],index=['maths','english','hindi','sciences'])
print(hello)
# Out:
# maths       10
# english     20
# hindi       30
# sciences    40
# dtype: int64

# %%
#dataframes
pd_1=pd.DataFrame(data={'names':"satya","age":21,"gender":"male"},index=[1,2,3,4])
print(pd_1)
# Out:
#    names  age gender
# 1  satya   21   male
# 2  satya   21   male
# 3  satya   21   male
# 4  satya   21   male

# %% [markdown]
# ### importing the data set into the notebook::::::

# %% [markdown]
# pd.read_csv('path' and ending file name with extension)

# %%
#ipl scorecard
data={"player":["virat","rohit","gill",'rahul',"hardik"],
     "runs":[100,99,34,21,45],
     "balls":[88,79,76,43,56]}
df=pd.DataFrame(data)
print(df.tail())
# Out:
#    player  runs  balls
# 0   virat   100     88
# 1   rohit    99     79
# 2    gill    34     76
# 3   rahul    21     43
# 4  hardik    45     56
