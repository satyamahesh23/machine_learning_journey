# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9112/3208854469.py in <module>
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9112/3208854469.py in <module>
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 26.1.2 is available.
# You should consider upgrading via the 'C:\Users\pavani\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=[1,2,3,4,5,6]
y=[10,2,5,9,4,9]
plt.plot(x,y)

# %%
runs=[259,280,220,300,275]
plt.plot(runs)
plt.show()
plt.xlabel("matches")
plt.ylabel('runs')
plt.title('india team runs')
plt.show()

# %%
x=[5,2,6,7]
y=[10,20,30,40]
plt.bar(x,y,color=['red','green','blue','pink'])
# Out:
# <BarContainer object of 4 artists>

# %%
players=['virat','rohit','gill','rahul']
runs=[90,45,100,56]
plt.bar(players,runs)
plt.show()

# %%
players=['virat','rohit','gill']
runs=[90,45,100]
plt.pie(runs,labels=players)
plt.show()

# %%
marks = [45,55,60,70,80,85,90,95]

plt.hist(marks)
plt.show()

# %%
height = [150,160,170,180,190]
weight = [50,60,70,80,90]
plt.scatter(height,weight)
plt.show()

# %%
import matplotlib.pyplot as plt

players = ["Virat","Rohit","Gill","Rahul","Hardik"]
runs = [90,45,100,56,32]

plt.bar(players,runs)
plt.scatter(players,runs)

plt.xlabel("Players")
plt.ylabel("Runs")
plt.title("India Scorecard")

plt.show()
