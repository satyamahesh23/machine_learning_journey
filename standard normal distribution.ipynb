# %%
import pandas as pd

# %%
df=pd.read_csv('BEML_lyst1729240526796.csv')
df
# Out:
#             Date     Open     High      Low     Last    Close  \
# 0     2010-01-04  1121.00  1151.00  1121.00  1134.00  1135.60
# 1     2010-01-05  1146.80  1149.00  1128.75  1135.00  1134.60
# 2     2010-01-06  1140.00  1164.25  1130.05  1137.00  1139.60
# 3     2010-01-07  1142.00  1159.40  1119.20  1141.00  1144.15
# 4     2010-01-08  1156.00  1172.00  1140.00  1141.20  1144.05
# ...          ...      ...      ...      ...      ...      ...
# 1734  2016-12-26   965.00   965.05   935.00   950.10   950.25
# 1735  2016-12-27   960.70   989.00   952.35   974.00   975.70
# 1736  2016-12-28   980.75   985.00   970.15   977.00   974.40
# 1737  2016-12-29   977.10   997.95   974.55   985.15   986.05
# 1738  2016-12-30   986.00  1006.95   985.90  1004.00  1000.60
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                 101651.0          1157.18
# 1                  59504.0           676.47
# 2                 128908.0          1482.84
# ...

# %% [raw]
# Step 1: What is Standard Normal Distribution?
#
# A standard normal distribution converts all values into a common scale called a Z-score.

# %%
df.describe()
# Out:
#               Open         High          Low         Last        Close  \
# count  1739.000000  1739.000000  1739.000000  1739.000000  1739.000000
# mean    700.233180   713.384704   686.280276   698.413370   698.435221
# std     358.658024   364.165083   351.554420   357.358712   357.429870
# min     129.300000   133.500000   106.000000   128.900000   129.150000
# 25%     371.025000   379.300000   367.525000   370.550000   370.650000
# 50%     685.000000   699.800000   666.750000   683.000000   682.150000
# 75%    1012.000000  1027.800000   997.000000  1011.200000  1010.550000
# max    1569.800000  1612.000000  1540.250000  1555.850000  1558.500000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          1.739000e+03      1739.000000
# mean           2.352309e+05      1682.773985
# std            3.561114e+05      2705.430289
# min            2.441000e+03        16.130000
# 25%            5.878150e+04       263.160000
# 50%            1.282050e+05       678.090000
# ...

# %%
mean=df['Close'].mean()
mean
# Out:
# np.float64(698.4352213916044)

# %%
std=df['Close'].std()
std
# Out:
# np.float64(357.42986982246737)

# %%
l=df['z-score']=(df['Close']-mean)/std
l.head()
# Out:
# 0    1.223078
# 1    1.220281
# 2    1.234269
# 3    1.246999
# 4    1.246719
# Name: Close, dtype: float64

# %%
df=(300-200)/50
df
# Out:
# 2.0

# %%
(60-80)/10
# Out:
# -2.0

# %%
(700-500)/100
# Out:
# 2.0

# %% [raw]
# Simple rule to remember:
# ( )  → First priority
# **   → Second priority
# * /  → Third priority
# + -  → Last priority

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('BEML_lyst1729240526796.csv')
df
# Out:
#             Date     Open     High      Low     Last    Close  \
# 0     2010-01-04  1121.00  1151.00  1121.00  1134.00  1135.60
# 1     2010-01-05  1146.80  1149.00  1128.75  1135.00  1134.60
# 2     2010-01-06  1140.00  1164.25  1130.05  1137.00  1139.60
# 3     2010-01-07  1142.00  1159.40  1119.20  1141.00  1144.15
# 4     2010-01-08  1156.00  1172.00  1140.00  1141.20  1144.05
# ...          ...      ...      ...      ...      ...      ...
# 1734  2016-12-26   965.00   965.05   935.00   950.10   950.25
# 1735  2016-12-27   960.70   989.00   952.35   974.00   975.70
# 1736  2016-12-28   980.75   985.00   970.15   977.00   974.40
# 1737  2016-12-29   977.10   997.95   974.55   985.15   986.05
# 1738  2016-12-30   986.00  1006.95   985.90  1004.00  1000.60
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                 101651.0          1157.18
# 1                  59504.0           676.47
# 2                 128908.0          1482.84
# ...

# %%
plt.hist(df['Close'],bins=30)
# Out:
# (array([146.,  99.,  48., 121.,  18.,  47.,  40.,  73.,  67.,  72.,  65.,
#         102.,  34.,  35.,  36.,  48.,  93.,  80., 160., 104.,  67.,  57.,
#          42.,  38.,  14.,  11.,   5.,   2.,   8.,   7.]),
#  array([ 129.15 ,  176.795,  224.44 ,  272.085,  319.73 ,  367.375,
#          415.02 ,  462.665,  510.31 ,  557.955,  605.6  ,  653.245,
#          700.89 ,  748.535,  796.18 ,  843.825,  891.47 ,  939.115,
#          986.76 , 1034.405, 1082.05 , 1129.695, 1177.34 , 1224.985,
#         1272.63 , 1320.275, 1367.92 , 1415.565, 1463.21 , 1510.855,
#         1558.5  ]),
#  <BarContainer object of 30 artists>)

# %%
plt.title("close")
plt.xlabel("close proce")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
mean=df['Close'].mean()
std=df['Close'].std()
mean
# Out:
# np.float64(698.4352213916044)

# %%
std
# Out:
# np.float64(357.42986982246737)

# %%
l=df['z-scre']=(df['Close']-mean)/std

# %%
l
# Out:
# 0       1.223078
# 1       1.220281
# 2       1.234269
# 3       1.246999
# 4       1.246719
#           ...
# 1734    0.704515
# 1735    0.775718
# 1736    0.772081
# 1737    0.804675
# 1738    0.845382
# Name: Close, Length: 1739, dtype: float64

# %%
plt.figure(figsize=(10,5))
plt.hist(df['z-scre'])
# Out:
# (array([293., 186., 180., 239., 105., 221., 331., 137.,  30.,  17.]),
#  array([-1.59271865, -1.19282203, -0.7929254 , -0.39302877,  0.00686786,
#          0.40676449,  0.80666112,  1.20655775,  1.60645438,  2.00635101,
#          2.40624763]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(df['z-scre'])
plt.axhline(y=3)
plt.axhline(y=-3)

# %%
plt.plot(df['Close'],label='original')
plt.plot(df['z-scre'],label='z-score')
plt.legend()

# %%
plt.hist(df['Close'],bins=30)
plt.show()
