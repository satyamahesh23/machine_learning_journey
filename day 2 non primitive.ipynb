# %% [markdown]
# # non-primitive data type

# %% [markdown]
# list , tuple , set , dict

# %% [markdown]
# ## list

# %%
list_1=[10,20,30,40,50,56.6,"stings",True,None]
#anytype of data type are accecptable in list::::::
##list is always going to get declared in square brackets
print(list_1)
# Out:
# [10, 20, 30, 40, 50, 56.6, 'stings', True, None]

# %%
print(list_1[0])
# Out:
# 10

# %%
list_1.append("hello")
print(list_1)
##this is add at the end of the list
##list are mutable mean we can change data
# Out:
# [10, 20, 30, 40, 50, 56.6, 'stings', True, None, 'hello', 'hello', 'hello']

# %%
list_1[4]="gojo"
print(list_1)
# Out:
# [10, 20, 30, 40, 'gojo', 56.6, 'stings', True, None, 'hello', 'hello', 'hello']

# %% [markdown]
# # tuples::::

# %%
tuple_1=(10,20,40,"string",[10,20,40])
print(tuple_1)
# Out:
# (10, 20, 40, 'string', [10, 20, 40])

# %% [markdown]
# #we can declare any data tyype inside in tuple
# #lists and tuples both follows indexing as well as slicing.
# #syntax for slicing
# #tuple_1=[start_index-1:stride/jumps]

# %%
print(tuple_1[1:4:2])
# Out:
# (20, 'string')

# %% [markdown]
# # sets:::::

# %%
set_1={10,20,30,"hey",True,10,10,10 21,21}
print(set_1)
#sets are unordered in nature
#sets does not follow indexing
# Out:
# {True, 'hey', 20, 10, 30}

# %%
print(set_1)
#sets wont give duplicates values
# Out:
# {True, 'hey', 20, 10, 30}

# %%
set_1.add("banana")
print(set_1)
#to add we need to keep add function
# Out:
# {True, 'hey', 'banana', 20, 10, 30}

# %% [markdown]
# # dictionary:::::

# %%
dict_1={"name":"satya mahesh","age":21,"gender":"male"}
print(dict_1)
#always we need to give key values pairs,and kamma always if not it gives error
#we can declare any data types values
#values can be duplicated
# Out:
# {'name': 'satya mahesh', 'age': 21, 'gender': 'male'}

# %%
dict_1.keys()
#keys are immutuable
#keys are uniques
# Out:
# dict_keys(['name', 'age', 'gender'])

# %%
dict_1.values()
#values are mutuable
# Out:
# dict_values(['satya mahesh', 21, 'male'])

# %%
dict_1["age"]=21
print(dict_1)
# Out:
# {'name': 'satya mahesh', 'age': 21, 'gender': 'male'}
