# %%
# !pip install pandas
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.1.2 is available.
# You should consider upgrading via the 'C:\Users\pavani\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# ...

# %%
import pandas  as pd

# %%
data={"name":['satya','mahesh']}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#      name
# 0   satya
# 1  mahesh
