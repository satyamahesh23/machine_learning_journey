# %%
import pandas as pd

# %%
df=pd.read_csv("Ecommerce_Customers_lyst1729240648301.csv")
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
# the dataset is about the consumers who buy cloths online the store offer in-store advice sessions.customers come into the store and have sessions with a prosonal

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
#seletcion of input target data feature

# %%
x=df.iloc[:,3:7].values
y=df.iloc[:,7:8].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=6)

# %%
#application of model

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# lm=LinearRegression()

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)

# %%
y_pred=lm.predict(x_test)

# %%
lm.score(x_train,y_train)
