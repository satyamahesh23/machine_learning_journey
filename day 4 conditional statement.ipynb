# %% [raw]
# conditional statement are the part of python program
# syntax:::
#             if condition:
#                  block of code # indentation is important
#             else:
#                  block of code
#                  ......

# %%
#find out if the number is divisile by 2
num_1=4
if  num_1%2==0:
    print("its divible")
else:
    print("no")
# Out:
# its divible

# %%
#if elif else:
